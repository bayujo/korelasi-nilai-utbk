# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
jurusan = pd.read_csv('majors.csv', encoding='utf-8')
soshum  = pd.read_csv('score_humanities.csv', encoding='utf-8')
saintek = pd.read_csv('score_science.csv', encoding='utf-8')
universitas = pd.read_csv('universities.csv', encoding='utf-8')

# %%
pd.set_option("display.max_rows", 1000, "display.max_columns", 1000)

# %%
jurusan.describe()
# Out:
#         Unnamed: 0      id_major  id_university     capacity
# count  3167.000000  3.167000e+03    3167.000000  3167.000000
# mean   1583.000000  4.216499e+06     421.488791    51.186612
# std     914.378477  2.239755e+06     223.976006    34.911506
# min       0.000000  1.111014e+06     111.000000     6.000000
# 25%     791.500000  3.211170e+06     321.000000    32.000000
# 50%    1583.000000  3.622257e+06     362.000000    44.000000
# 75%    2374.500000  6.121160e+06     612.000000    60.000000
# max    3166.000000  9.212073e+06     921.000000   425.000000

# %%
soshum.describe()
# Out:
#          Unnamed: 0  id_first_major  id_first_university  id_second_major  \
# count  61202.000000    6.120200e+04         61202.000000     6.120200e+04
# mean   30600.500000    3.494004e+06           349.239110     3.480706e+06
# std    17667.639924    9.841163e+05            98.362137     1.062845e+06
# min        0.000000    2.530000e+02             9.000000     2.530000e+02
# 25%    15300.250000    3.242025e+06           324.000000     3.242056e+06
# 50%    30600.500000    3.532243e+06           353.000000     3.532332e+06
# 75%    45900.750000    3.712175e+06           371.000000     3.722034e+06
# max    61201.000000    9.212073e+06           921.000000     9.212073e+06
#
#        id_second_university        id_user     score_eko     score_geo  \
# count          61202.000000   61202.000000  61202.000000  61202.000000
# mean             347.903287  184678.938286    547.778259    546.765629
# std              106.223687   93047.899031    100.337350     94.413754
# ...

# %%
saintek.describe()
# Out:
#          Unnamed: 0  id_first_major  id_first_university  id_second_major  \
# count  86570.000000    8.657000e+04         86570.000000     8.657000e+04
# mean   43284.500000    3.510065e+06           350.987317     3.482497e+06
# std    24990.750739    1.192799e+06           119.206515     1.258767e+06
# min        0.000000    1.496000e+03            46.000000     1.025000e+03
# 25%    21642.250000    3.311094e+06           331.000000     3.241092e+06
# 50%    43284.500000    3.531313e+06           353.000000     3.531321e+06
# 75%    64926.750000    3.721232e+06           372.000000     3.721263e+06
# max    86569.000000    9.211352e+06           921.000000     9.211352e+06
#
#        id_second_university        id_user     score_bio     score_fis  \
# count          86570.000000   86570.000000  86570.000000  86570.000000
# mean             348.189199  177509.875523    537.140522    539.335312
# std              125.840155   95418.883782     96.596624    102.293095
# ...

# %%
df = pd.merge(jurusan, universitas, left_on='id_university',right_on='id_university',how='outer',suffixes=('_left','_right'))
#df.loc[df['capacity'] == 425]

# %%
df.groupby('university_name')['capacity'].sum()
# Out:
# university_name
# INSTITUT PERTANIAN BOGOR                         1693
# INSTITUT TEKNOLOGI BANDUNG                       1644
# INSTITUT TEKNOLOGI KALIMANTAN                     582
# INSTITUT TEKNOLOGI SEPULUH NOPEMBER              1595
# INSTITUT TEKNOLOGI SUMATERA                      1968
# ISBI ACEH                                          72
# ISBI BANDUNG                                      183
# ISBI TANAH PAPUA                                   53
# ISI DENPASAR                                      200
# ISI PADANG PANJANG                                395
# ISI SURAKARTA                                     460
# ISI YOGYAKARTA                                    492
# UNIVERSITAS AIRLANGGA                            2194
# UNIVERSITAS ANDALAS                              2312
# UNIVERSITAS BANGKA BELITUNG                       528
# UNIVERSITAS BENGKULU                             2103
# UNIVERSITAS BORNEO TARAKAN                        738
# ...

# %%
merged_saintek = universitas.merge(saintek,left_on='id_university',right_on='id_first_university')
major_score_corr = saintek.merge(jurusan, left_on='id_first_major',right_on='id_major').merge(universitas, left_on='id_first_university',right_on='id_university')
merged_soshum = jurusan.merge(soshum,left_on='id_major',right_on='id_first_major') #.merge(universitas,on='id_university')
#merged_saintek = merged_saintek[merged_saintek.id_first_university == 321]

# %%
jurusan
# Out:
#       Unnamed: 0  id_major  id_university        type  \
# 0              0   1111014            111     science
# 1              1   1111022            111     science
# 2              2   1111037            111     science
# 3              3   1111045            111     science
# 4              4   1111053            111     science
# ...          ...       ...            ...         ...
# 3162        3162   9212011            921  humanities
# 3163        3163   9212042            921  humanities
# 3164        3164   9212057            921  humanities
# 3165        3165   9212065            921  humanities
# 3166        3166   9212073            921  humanities
#
#                        major_name  capacity
# 0         PENDIDIKAN DOKTER HEWAN        88
# 1                    TEKNIK SIPIL        64
# 2                    TEKNIK MESIN        48
# 3                    TEKNIK KIMIA        48
# 4                      ARSITEKTUR        48
# ...                           ...       ...
# ...

# %%
saintek
# Out:
#        Unnamed: 0  id_first_major  id_first_university  id_second_major  \
# 0               0         3321065                  332          3331187
# 1               1         3211015                  321          3611066
# 2               2         3721093                  372          3551302
# 3               3         3321096                  332          3551194
# 4               4         5211104                  521          5211085
# ...           ...             ...                  ...              ...
# 86565       86565         1411161                  141          1421147
# 86566       86566         3561262                  356          3571055
# 86567       86567         3531182                  353          3561022
# 86568       86568         1121094                  112          1221095
# 86569       86569         1911286                  191          1921056
#
#        id_second_university  id_user  score_bio  score_fis  score_kim  \
# ...

# %%
merged_saintek = merged_saintek.loc[:, ~merged_saintek.columns.str.contains('^Unnamed')]
#merged_saintek = merged_saintek.loc[:, ~merged_saintek.columns.str.contains('^university_name')]
merged_saintek = merged_saintek.loc[:, ~merged_saintek.columns.str.contains('^type')]
merged_saintek = merged_saintek.loc[:, ~merged_saintek.columns.str.contains('^id_major')]
merged_saintek = merged_saintek.loc[:, ~merged_saintek.columns.str.contains('^capacity')]
merged_saintek = merged_saintek.loc[:, ~merged_saintek.columns.str.contains('^id_first_major')]
merged_saintek = merged_saintek.loc[:, ~merged_saintek.columns.str.contains('^id_first_university')]
merged_saintek = merged_saintek.loc[:, ~merged_saintek.columns.str.contains('^id_second_major')]
merged_saintek = merged_saintek.loc[:, ~merged_saintek.columns.str.contains('^id_second_university')]
merged_saintek = merged_saintek.loc[:, ~merged_saintek.columns.str.contains('^id_user')]
#merged_saintek = merged_saintek.loc[:, ~merged_saintek.columns.str.contains('^score_mat')]
#merged_saintek = merged_saintek.loc[:, ~merged_saintek.columns.str.contains('^score_ppu')]
#merged_saintek = merged_saintek.loc[:, ~merged_saintek.columns.str.contains('^score_kua')]
#merged_saintek = merged_saintek.loc[:, ~merged_saintek.columns.str.contains('^score_kpu')]
#merged_saintek = merged_saintek.loc[:, ~merged_saintek.columns.str.contains('^score_kmb')]
#merged_saintek = merged_saintek.loc[:, ~merged_saintek.columns.str.contains('^score_bio')]
#merged_saintek = merged_saintek.loc[:, ~merged_saintek.columns.str.contains('^score_fis')]

merged_soshum = merged_soshum.loc[:, ~merged_soshum.columns.str.contains('^Unnamed')]
merged_soshum = merged_soshum.loc[:, ~merged_soshum.columns.str.contains('^id_university')]

# %%
merged_soshum
# Out:
#        id_major        type                 major_name  capacity  \
# 0       1112017  humanities        EKONOMI PEMBANGUNAN        64
# 1       1112017  humanities        EKONOMI PEMBANGUNAN        64
# 2       1112017  humanities        EKONOMI PEMBANGUNAN        64
# 3       1112017  humanities        EKONOMI PEMBANGUNAN        64
# 4       1112017  humanities        EKONOMI PEMBANGUNAN        64
# ...         ...         ...                        ...       ...
# 61193   9212073  humanities  PENDIDIKAN BAHASA INGGRIS        16
# 61194   9212073  humanities  PENDIDIKAN BAHASA INGGRIS        16
# 61195   9212073  humanities  PENDIDIKAN BAHASA INGGRIS        16
# 61196   9212073  humanities  PENDIDIKAN BAHASA INGGRIS        16
# 61197   9212073  humanities  PENDIDIKAN BAHASA INGGRIS        16
#
#        id_first_major  id_first_university  id_second_major  \
# 0             1112017                  111          1122012
# 1             1112017                  111          3832293
# ...

# %%
merged_saintek
# Out:
#        id_university          university_name  score_bio  score_fis  \
# 0                111  UNIVERSITAS SYIAH KUALA        437        522
# 1                111  UNIVERSITAS SYIAH KUALA        464        463
# 2                111  UNIVERSITAS SYIAH KUALA        621        451
# 3                111  UNIVERSITAS SYIAH KUALA        436        400
# 4                111  UNIVERSITAS SYIAH KUALA        452        731
# ...              ...                      ...        ...        ...
# 86564            921        UNIVERSITAS PAPUA        501        524
# 86565            921        UNIVERSITAS PAPUA        539        634
# 86566            921        UNIVERSITAS PAPUA        389        463
# 86567            921        UNIVERSITAS PAPUA        474        634
# 86568            921        UNIVERSITAS PAPUA        507        495
#
#        score_kim  score_kmb  score_kpu  score_kua  score_mat  score_ppu
# 0            446        538        597        427        389        574
# ...

# %%
#merged_saintek['rata_rata'] = ((merged_saintek['score_bio']+merged_saintek['score_fis']+merged_saintek['score_kim']+merged_saintek['score_mat'])/4*0.3)+((merged_saintek['score_kpu']+merged_saintek['score_kua']+merged_saintek['score_kmb']+merged_saintek['score_ppu'])/4*0.7)

merged_saintek['rata_rata'] = (merged_saintek['score_bio']+merged_saintek['score_fis']+merged_saintek['score_kim']+merged_saintek['score_mat']+merged_saintek['score_kpu']+merged_saintek['score_kua']+merged_saintek['score_kmb']+merged_saintek['score_ppu'])/8

# %%
merged_saintek
# Out:
#        id_university          university_name  score_bio  score_fis  \
# 0                111  UNIVERSITAS SYIAH KUALA        437        522
# 1                111  UNIVERSITAS SYIAH KUALA        464        463
# 2                111  UNIVERSITAS SYIAH KUALA        621        451
# 3                111  UNIVERSITAS SYIAH KUALA        436        400
# 4                111  UNIVERSITAS SYIAH KUALA        452        731
# ...              ...                      ...        ...        ...
# 86564            921        UNIVERSITAS PAPUA        501        524
# 86565            921        UNIVERSITAS PAPUA        539        634
# 86566            921        UNIVERSITAS PAPUA        389        463
# 86567            921        UNIVERSITAS PAPUA        474        634
# 86568            921        UNIVERSITAS PAPUA        507        495
#
#        score_kim  score_kmb  score_kpu  score_kua  score_mat  score_ppu  \
# 0            446        538        597        427        389        574
# ...

# %% [markdown]
# x=range(len(merged_saintek))
# sns.scatterplot(x=x, y='score_bio',data=merged_saintek,hue='major_name')
# plt.show()
# encoder=LabelEncoder()
# encoder.fit(merged_saintek['major_name'])
# merged_saintek['major_name_enc']=encoder.transform(merged_saintek['major_name'])
# corr=merged_saintek['score_bio'].corr(merged_saintek['major_name_enc'])
# print("correlation ",corr)

# %%
merged_saintek = merged_saintek.loc[:, ~merged_saintek.columns.str.contains('^score_mat')]
merged_saintek = merged_saintek.loc[:, ~merged_saintek.columns.str.contains('^score_ppu')]
merged_saintek = merged_saintek.loc[:, ~merged_saintek.columns.str.contains('^score_kua')]
merged_saintek = merged_saintek.loc[:, ~merged_saintek.columns.str.contains('^score_kpu')]
merged_saintek = merged_saintek.loc[:, ~merged_saintek.columns.str.contains('^score_kmb')]
merged_saintek = merged_saintek.loc[:, ~merged_saintek.columns.str.contains('^score_bio')]
merged_saintek = merged_saintek.loc[:, ~merged_saintek.columns.str.contains('^score_fis')]
merged_saintek = merged_saintek.loc[:, ~merged_saintek.columns.str.contains('^score_kim')]

# %%
merged_saintek
# Out:
#        id_university          university_name  rata_rata
# 0                111  UNIVERSITAS SYIAH KUALA    491.250
# 1                111  UNIVERSITAS SYIAH KUALA    500.375
# 2                111  UNIVERSITAS SYIAH KUALA    571.125
# 3                111  UNIVERSITAS SYIAH KUALA    471.250
# 4                111  UNIVERSITAS SYIAH KUALA    490.250
# ...              ...                      ...        ...
# 86564            921        UNIVERSITAS PAPUA    531.750
# 86565            921        UNIVERSITAS PAPUA    529.750
# 86566            921        UNIVERSITAS PAPUA    473.375
# 86567            921        UNIVERSITAS PAPUA    506.000
# 86568            921        UNIVERSITAS PAPUA    502.000
#
# [86569 rows x 3 columns]

# %% [markdown]
# x=range(len(merged_saintek))
# sns.scatterplot(x=x, y='rata_rata',data=merged_saintek,hue='university_name')
# plt.show()
# encoder=LabelEncoder()
# encoder.fit(merged_saintek['university_name'])
# merged_saintek['university_encoded']=encoder.transform(merged_saintek['university_name'])
# corr=merged_saintek['rata_rata'].corr(merged_saintek['university_encoded'])
# print("correlation ",corr)

# %%
sns.heatmap(merged_saintek.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x='id_university', y ='rata_rata' ,data = merged_saintek)
# Out:
# <AxesSubplot:xlabel='id_university', ylabel='rata_rata'>

# %%
major_score_corr = major_score_corr.loc[major_score_corr['university_name'] == 'UNIVERSITAS BRAWIJAYA']

# %%
major_score_corr = major_score_corr.loc[:, ~major_score_corr.columns.str.contains('^Unnamed')]
major_score_corr = major_score_corr.loc[:, ~major_score_corr.columns.str.contains('^id_second_major')]
major_score_corr = major_score_corr.loc[:, ~major_score_corr.columns.str.contains('^id_first_university')]
major_score_corr = major_score_corr.loc[:, ~major_score_corr.columns.str.contains('^id_user')]
major_score_corr = major_score_corr.loc[:, ~major_score_corr.columns.str.contains('^type')]
major_score_corr = major_score_corr.loc[:, ~major_score_corr.columns.str.contains('^capacity')]
major_score_corr = major_score_corr.loc[:, ~major_score_corr.columns.str.contains('^id_university_y')]
major_score_corr = major_score_corr.loc[:, ~major_score_corr.columns.str.contains('^id_university_x')]
major_score_corr = major_score_corr.loc[:, ~major_score_corr.columns.str.contains('^id_second_university')]
major_score_corr = major_score_corr.loc[:, ~major_score_corr.columns.str.contains('^university_name')]
major_score_corr = major_score_corr.loc[:, ~major_score_corr.columns.str.contains('^id_first_major')]

# %%
major_score_corr['rata_rata'] = ((major_score_corr['score_bio']+major_score_corr['score_fis']+major_score_corr['score_kim']+major_score_corr['score_mat'])/4*0.3)+((major_score_corr['score_kpu']+major_score_corr['score_kua']+major_score_corr['score_kmb']+major_score_corr['score_ppu'])/4*0.7)

# %%
major_score_corr = major_score_corr.loc[:, ~major_score_corr.columns.str.contains('^score_mat')]
major_score_corr = major_score_corr.loc[:, ~major_score_corr.columns.str.contains('^score_ppu')]
major_score_corr = major_score_corr.loc[:, ~major_score_corr.columns.str.contains('^score_kua')]
major_score_corr = major_score_corr.loc[:, ~major_score_corr.columns.str.contains('^score_kpu')]
major_score_corr = major_score_corr.loc[:, ~major_score_corr.columns.str.contains('^score_kmb')]
major_score_corr = major_score_corr.loc[:, ~major_score_corr.columns.str.contains('^score_bio')]
major_score_corr = major_score_corr.loc[:, ~major_score_corr.columns.str.contains('^score_fis')]
major_score_corr = major_score_corr.loc[:, ~major_score_corr.columns.str.contains('^score_kim')]

# %%
major_score_corr
# Out:
#        id_major                      major_name  rata_rata
# 12700   3721093       ILMU DAN TEKNOLOGI PANGAN    650.475
# 12701   3721093       ILMU DAN TEKNOLOGI PANGAN    434.300
# 12702   3721093       ILMU DAN TEKNOLOGI PANGAN    580.525
# 12703   3721093       ILMU DAN TEKNOLOGI PANGAN    492.325
# 12704   3721093       ILMU DAN TEKNOLOGI PANGAN    617.600
# ...         ...                             ...        ...
# 18903   3721472  PENDIDIKAN TEKNOLOGI INFORMASI    552.050
# 18904   3721472  PENDIDIKAN TEKNOLOGI INFORMASI    596.125
# 18905   3721472  PENDIDIKAN TEKNOLOGI INFORMASI    568.550
# 18906   1711311                      PETERNAKAN    585.675
# 18907   1141013                   AGROTEKNOLOGI    467.975
#
# [6208 rows x 3 columns]

# %%
sns.heatmap(major_score_corr.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot( x= 'id_major', y= 'rata_rata',data = major_score_corr)
# Out:
# <AxesSubplot:xlabel='id_major', ylabel='rata_rata'>

# %%
major_score_corr
# Out:
#        id_major                      major_name  rata_rata
# 12700   3721093       ILMU DAN TEKNOLOGI PANGAN    650.475
# 12701   3721093       ILMU DAN TEKNOLOGI PANGAN    434.300
# 12702   3721093       ILMU DAN TEKNOLOGI PANGAN    580.525
# 12703   3721093       ILMU DAN TEKNOLOGI PANGAN    492.325
# 12704   3721093       ILMU DAN TEKNOLOGI PANGAN    617.600
# ...         ...                             ...        ...
# 18903   3721472  PENDIDIKAN TEKNOLOGI INFORMASI    552.050
# 18904   3721472  PENDIDIKAN TEKNOLOGI INFORMASI    596.125
# 18905   3721472  PENDIDIKAN TEKNOLOGI INFORMASI    568.550
# 18906   1711311                      PETERNAKAN    585.675
# 18907   1141013                   AGROTEKNOLOGI    467.975
#
# [6208 rows x 3 columns]

# %%
sns.boxplot(data = saintek[saintek.columns[6:10]],orient="h")
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data = saintek[saintek.columns[10:14]],orient="h")
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x = jurusan[jurusan.columns[5]])
# Out:
# <AxesSubplot:xlabel='capacity'>
